# %%
# Lets try to make an AI avatar
# Install osc
# %pip install python-osc

# %%
# Generate a sample sound
# %pip install -U sounddevice numpy

# %%
from IPython.display import Audio, display

# Load and play the audio file
audio_file = '../audios/test.mp3'
display(Audio(audio_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pyaudio

p = pyaudio.PyAudio()

print("Available audio output devices:")
for i in range(p.get_device_count()):
    info = p.get_device_info_by_index(i)
    if info.get('max_output_channels') > 0: # Filter for output devices
        print(f"  Device {i}: {info.get('name')}")

p.terminate()
# Out:
# Available audio output devices:

# %%
# Elevn labs integration test
# %pip install -q -U elevenlabs python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs
from elevenlabs import play

load_dotenv()

elevenlabs = ElevenLabs(
    api_key=os.getenv("ELEVENLABS_API_KEY"),
)

prompt = "The secret of life is 42. And I will not stand for any other interpretation."
audio = elevenlabs.text_to_speech.convert(
    text=prompt,
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_multilingual_v2",
    output_format="mp3_44100_128",
)

play(audio)

# %%
play(audio)

# %%
from elevenlabs.client import ElevenLabs

client = ElevenLabs(
    api_key=os.getenv("ELEVENLABS_API_KEY"),
)

response = client.voices.search()
print(response.voices)

for voice in response.voices:
    print(f"- {voice.name} (ID: {voice.voice_id})")
# Out:
# [Voice(voice_id='21m00Tcm4TlvDq8ikWAM', name='Rachel', samples=None, category='premade', fine_tuning=FineTuningResponse(is_allowed_to_fine_tune=False, state={}, verification_failures=[], verification_attempts_count=0, manual_verification_requested=False, language=None, progress={}, message={}, dataset_duration_seconds=None, verification_attempts=None, slice_ids=None, manual_verification=None, max_verification_attempts=None, next_max_verification_attempts_reset_unix_ms=None, finetuning_state=None), labels={'accent': 'american', 'description': 'calm', 'age': 'young', 'gender': 'female', 'use_case': 'narration'}, description=None, preview_url='https://storage.googleapis.com/eleven-public-prod/premade/voices/21m00Tcm4TlvDq8ikWAM/b4928a68-c03b-411f-8533-3d5c299fd451.mp3', available_for_tiers=[], settings=None, sharing=None, high_quality_base_model_ids=[], verified_languages=[], safety_control=None, voice_verification=VoiceVerificationResponse(requires_verification=False, is_verified=False
# ...

# %%
from elevenlabs import stream
from elevenlabs.client import ElevenLabs

client = ElevenLabs(
    api_key=os.getenv("ELEVENLABS_API_KEY"),
)

audio_stream = client.text_to_speech.stream(
    text="The secret of life is 42. And I will not stand for any other interpretation.",
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_multilingual_v2",
)

stream(audio_stream)
# Out:
# b'ID3\x04\x00\x00\x00\x00\x00#TSSE\x00\x00\x00\x0f\x00\x00\x03Lavf59.27.100\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\xfb\x90\xc4\x00\x02\x14\x91\x90\xf4\xa7\xb0\xc3\x8a\xd5\xbf`\x05\x83&y\x00 !^\x1c\x03\x81@\x94\x13\x03\xe0\xdc\t\x80\x00\x1c&9\xa7bY\x99\x98\x90`\xb1\xc8!\x11\x17\xad\x9f\xe1\xe9\x98\x08\x10B?\xf6C\x1c\xf0p\xb2`\xe1`\x00\x02\x11\x1e\xee\xc8De\x93&M<\xeeL\x990\x18\x0c-\x0f\xf9\xf6\xd1\x04\xcf\x07\x01\x85\x93&\x16\x9e2\x0e\xc4 \xc2\t\x93&\x9f\xbdrx\xfe\x1e\xe0\xfd\xdc\xbe~\x99\x10\xce\x0e<\xcc\xd7\xbb\x8fg\xee\x1e\x9c yD\x1f`\xc2i\xb2\x07\xac\x81k\xd4\x1fq\xb3^\x0f\xb3\xc0u\x19d0\x9d\x02 b\x10\x9b\x03\xc0"|\x0e;\xfe\xfd\x0fO\x80\x03\xb0\x0f?\xff_\xe0\x02\x00?\x01\x00\x8b\xd4o\xac:\xec\xbf7)y\x8c\xa63\x19\x96\xc35s\xb3\x8d\xdd\xf3z\xb3\xee\xd4d\xc7yb\x9c\xf95\xe0\xd2\xcd\xc3qM\x9c\xad\x05\x05\x90TBp\x8dt\xf9\xa5\x19\t\x11R!6\x8b\xbdb\r\x04\x16\x95\xa5%\x91+!\xa1y\x16D\x91\xafW\xcfb\x82\xd0(\xda6\x18r\xea/k=9\xb4a\x12\x8e\x9e\x9dn\x8d\x19}\xd1"\xe24\x99,Hy\xa3D(\xc5
# ...

# %%
stream(audio_stream)
# Out:
# b''
